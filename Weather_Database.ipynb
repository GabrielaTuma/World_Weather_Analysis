# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# The zip object packs each pair of lats and lngs having the same index in their 
# respective array into a tuple

# %%
coordinates = list(lat_lngs)

cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 775

# %%
url = "&appid=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")


# Create counters.
record_count = 1
set_count = 1   

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    # city_url = url + "&q=" + city.replace(" ","+")
    city_url = "http://api.openweathermap.org/data/2.5/weather?q=" + city.replace(" ","+") + url
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_name = city_weather["name"]
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        
        city_description = city_weather["weather"]
        city_description_df = pd.DataFrame(city_description)
        city_desc = city_description_df["description"].item()
  
        # Append the city information into city_data list.
        city_data.append({"City": city_name,
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lavrentiya
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | linkou
# Processing Record 4 of Set 1 | schwedt
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | lorengau
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | upernavik
# Processing Record 9 of Set 1 | nhulunbuy
# Processing Record 10 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 1 | narsaq
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | hobyo
# Processing Record 14 of Set 1 | mastic beach
# City not found. Skipping...
# Processing Record 15 of Set 1 | mocambique
# City not found. Skipping...
# Processing Record 16 of Set 1 | new norfolk
# Processing Record 17 of Set 1 | vulcan
# Processing Record 18 of Set 1 | dikson
# Processing Record 19 of Set 1 | te anau
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | hualmay
# Processing Record 23 of Set 1 | avanigadda
# Processing Record 24 of Set 1 | kodiak
# Processing Record 25 of Set 1 | oistins
# Processing Record 26 of Set 1 | minab
# Processing Record 27 of Set 1 | mahebourg
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | el cobre
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | talnakh
# Processing Record 32 of Set 1 | tasiilaq
# Processing Record 33 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 34 of Set 1 | baiyin
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | chenzhou
# Processing Record 37 of Set 1 | chifeng
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | flin flon
# Processing Record 40 of Set 1 | khatanga
# Processing Record 41 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 1 | vila
# Processing Record 43 of Set 1 | kruisfontein
# Processing Record 44 of Set 1 | kapoeta
# Processing Record 45 of Set 1 | poso
# Processing Record 46 of Set 1 | vagay
# Processing Record 47 of Set 1 | bonavista
# Processing Record 48 of Set 1 | xiaoweizhai
# Processing Record 49 of Set 1 | tevriz
# Processing Record 50 of Set 1 | mount isa
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | mar del plata
# Processing Record 3 of Set 2 | linhares
# Processing Record 4 of Set 2 | brae
# Processing Record 5 of Set 2 | ushuaia
# Processing Record 6 of Set 2 | giugliano in campania
# Processing Record 7 of Set 2 | grand gaube
# Processing Record 8 of Set 2 | lakselv
# Processing Record 9 of Set 2 | qaanaaq
# Processing Record 10 of Set 2 | bluff
# Processing Record 11 of Set 2 | hasaki
# Processing Record 12 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 2 | rio pardo de minas
# Processing Record 14 of Set 2 | brownsville
# Processing Record 15 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 16 of Set 2 | krasnoselkup
# Processing Record 17 of Set 2 | cabo san lucas
# Processing Record 18 of Set 2 | nusaybin
# Processing Record 19 of Set 2 | hilo
# Processing Record 20 of Set 2 | torbay
# Processing Record 21 of Set 2 | tiksi
# Processing Record 22 of Set 2 | saint-philippe
# Processing Record 23 of Set 2 | arraial do cabo
# Processing Record 24 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 2 | severodvinsk
# Processing Record 26 of Set 2 | kaitangata
# Processing Record 27 of Set 2 | henties bay
# Processing Record 28 of Set 2 | aksarka
# Processing Record 29 of Set 2 | chimoio
# Processing Record 30 of Set 2 | saint george
# Processing Record 31 of Set 2 | cape town
# Processing Record 32 of Set 2 | campbell river
# Processing Record 33 of Set 2 | calabar
# Processing Record 34 of Set 2 | duki
# Processing Record 35 of Set 2 | chokwe
# Processing Record 36 of Set 2 | tucuman
# Processing Record 37 of Set 2 | ribeira grande
# Processing Record 38 of Set 2 | guiratinga
# Processing Record 39 of Set 2 | eyrarbakki
# Processing Record 40 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 41 of Set 2 | dingle
# Processing Record 42 of Set 2 | ostrovnoy
# Processing Record 43 of Set 2 | ancud
# Processing Record 44 of Set 2 | panguna
# Processing Record 45 of Set 2 | manjacaze
# Processing Record 46 of Set 2 | robertsport
# Processing Record 47 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 2 | kodinsk
# Processing Record 49 of Set 2 | adrar
# Processing Record 50 of Set 2 | castro
# Processing Record 1 of Set 3 | meulaboh
# Processing Record 2 of Set 3 | guerrero negro
# Processing Record 3 of Set 3 | russell
# Processing Record 4 of Set 3 | jhargram
# Processing Record 5 of Set 3 | kapaa
# Processing Record 6 of Set 3 | mangrol
# Processing Record 7 of Set 3 | ribas do rio pardo
# Processing Record 8 of Set 3 | mataura
# Processing Record 9 of Set 3 | saskylakh
# Processing Record 10 of Set 3 | iqaluit
# Processing Record 11 of Set 3 | thunder bay
# Processing Record 12 of Set 3 | kyshtovka
# Processing Record 13 of Set 3 | goderich
# Processing Record 14 of Set 3 | albany
# Processing Record 15 of Set 3 | tilichiki
# Processing Record 16 of Set 3 | atuona
# Processing Record 17 of Set 3 | tarakan
# Processing Record 18 of Set 3 | bethel
# Processing Record 19 of Set 3 | puro
# Processing Record 20 of Set 3 | beziers
# Processing Record 21 of Set 3 | safaga
# Processing Record 22 of Set 3 | lompoc
# Processing Record 23 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 3 | alyangula
# Processing Record 25 of Set 3 | uravakonda
# Processing Record 26 of Set 3 | punta arenas
# Processing Record 27 of Set 3 | uren
# Processing Record 28 of Set 3 | kavieng
# Processing Record 29 of Set 3 | hithadhoo
# Processing Record 30 of Set 3 | ponta do sol
# Processing Record 31 of Set 3 | pevek
# Processing Record 32 of Set 3 | tautira
# Processing Record 33 of Set 3 | masindi
# Processing Record 34 of Set 3 | grindavik
# Processing Record 35 of Set 3 | east chicago
# Processing Record 36 of Set 3 | caravelas
# Processing Record 37 of Set 3 | faya
# Processing Record 38 of Set 3 | asau
# Processing Record 39 of Set 3 | clyde river
# Processing Record 40 of Set 3 | hobart
# Processing Record 41 of Set 3 | carora
# Processing Record 42 of Set 3 | de aar
# Processing Record 43 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 3 | hanyang
# Processing Record 45 of Set 3 | maningrida
# Processing Record 46 of Set 3 | chapais
# Processing Record 47 of Set 3 | sorland
# Processing Record 48 of Set 3 | chuy
# Processing Record 49 of Set 3 | vila franca do campo
# Processing Record 50 of Set 3 | nantucket
# Processing Record 1 of Set 4 | kuytun
# Processing Record 2 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 4 | ondjiva
# Processing Record 4 of Set 4 | praia da vitoria
# Processing Record 5 of Set 4 | kapit
# Processing Record 6 of Set 4 | gorontalo
# Processing Record 7 of Set 4 | svetlogorsk
# Processing Record 8 of Set 4 | kavaratti
# Processing Record 9 of Set 4 | nanortalik
# Processing Record 10 of Set 4 | santa isabel do rio negro
# Processing Record 11 of Set 4 | sfantu gheorghe
# Processing Record 12 of Set 4 | georgetown
# Processing Record 13 of Set 4 | huarmey
# Processing Record 14 of Set 4 | yarmouth
# Processing Record 15 of Set 4 | sobolevo
# Processing Record 16 of Set 4 | the valley
# Processing Record 17 of Set 4 | andenes
# City not found. Skipping...
# Processing Record 18 of Set 4 | dauphin
# Processing Record 19 of Set 4 | constitucion
# Processing Record 20 of Set 4 | winneba
# Processing Record 21 of Set 4 | biltine
# Processing Record 22 of Set 4 | ankpa
# Processing Record 23 of Set 4 | codrington
# Processing Record 24 of Set 4 | hofn
# Processing Record 25 of Set 4 | vaini
# Processing Record 26 of Set 4 | padang
# Processing Record 27 of Set 4 | victoria
# Processing Record 28 of Set 4 | bonthe
# Processing Record 29 of Set 4 | soure
# Processing Record 30 of Set 4 | avera
# Processing Record 31 of Set 4 | bambous virieux
# Processing Record 32 of Set 4 | aklavik
# Processing Record 33 of Set 4 | mozarlandia
# Processing Record 34 of Set 4 | cap-aux-meules
# Processing Record 35 of Set 4 | san patricio
# Processing Record 36 of Set 4 | lavumisa
# Processing Record 37 of Set 4 | chamba
# Processing Record 38 of Set 4 | kajaani
# Processing Record 39 of Set 4 | barrow
# Processing Record 40 of Set 4 | eyl
# Processing Record 41 of Set 4 | charters towers
# Processing Record 42 of Set 4 | xichang
# Processing Record 43 of Set 4 | komsomolskiy
# Processing Record 44 of Set 4 | vanavara
# Processing Record 45 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 4 | belz
# Processing Record 47 of Set 4 | beringovskiy
# Processing Record 48 of Set 4 | plettenberg bay
# Processing Record 49 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 4 | russellville
# Processing Record 1 of Set 5 | klaksvik
# Processing Record 2 of Set 5 | ankazoabo
# Processing Record 3 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 5 | gandu
# Processing Record 5 of Set 5 | mackay
# Processing Record 6 of Set 5 | mersing
# Processing Record 7 of Set 5 | katsuura
# Processing Record 8 of Set 5 | puerto del rosario
# Processing Record 9 of Set 5 | geraldton
# Processing Record 10 of Set 5 | balkhash
# Processing Record 11 of Set 5 | ibra
# Processing Record 12 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 5 | pangnirtung
# Processing Record 14 of Set 5 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 15 of Set 5 | itarema
# Processing Record 16 of Set 5 | aykhal
# Processing Record 17 of Set 5 | namibe
# Processing Record 18 of Set 5 | yumen
# Processing Record 19 of Set 5 | port augusta
# Processing Record 20 of Set 5 | shimoda
# Processing Record 21 of Set 5 | acarau
# Processing Record 22 of Set 5 | talaya
# Processing Record 23 of Set 5 | roma
# Processing Record 24 of Set 5 | chokurdakh
# Processing Record 25 of Set 5 | noumea
# Processing Record 26 of Set 5 | sao filipe
# Processing Record 27 of Set 5 | rio grande
# Processing Record 28 of Set 5 | huanren
# Processing Record 29 of Set 5 | abong mbang
# Processing Record 30 of Set 5 | esperance
# Processing Record 31 of Set 5 | omboue
# Processing Record 32 of Set 5 | east london
# Processing Record 33 of Set 5 | makat
# Processing Record 34 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 5 | vao
# Processing Record 36 of Set 5 | tuktoyaktuk
# Processing Record 37 of Set 5 | krasni okny
# Processing Record 38 of Set 5 | tuatapere
# Processing Record 39 of Set 5 | ramnagar
# Processing Record 40 of Set 5 | ionia
# Processing Record 41 of Set 5 | novobureyskiy
# Processing Record 42 of Set 5 | catamarca
# Processing Record 43 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 44 of Set 5 | birao
# Processing Record 45 of Set 5 | airai
# Processing Record 46 of Set 5 | leningradskiy
# Processing Record 47 of Set 5 | karakendzha
# City not found. Skipping...
# Processing Record 48 of Set 5 | parkes
# Processing Record 49 of Set 5 | nome
# Processing Record 50 of Set 5 | bandarbeyla
# Processing Record 1 of Set 6 | ukiah
# Processing Record 2 of Set 6 | seoul
# Processing Record 3 of Set 6 | livermore
# Processing Record 4 of Set 6 | port alfred
# Processing Record 5 of Set 6 | sinjai
# Processing Record 6 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 7 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 6 | gat
# Processing Record 9 of Set 6 | salinopolis
# Processing Record 10 of Set 6 | rock springs
# Processing Record 11 of Set 6 | tabou
# Processing Record 12 of Set 6 | impfondo
# Processing Record 13 of Set 6 | qui nhon
# Processing Record 14 of Set 6 | berlevag
# Processing Record 15 of Set 6 | sisimiut
# Processing Record 16 of Set 6 | rincon
# Processing Record 17 of Set 6 | longyearbyen
# Processing Record 18 of Set 6 | miquelon
# Processing Record 19 of Set 6 | at-bashi
# Processing Record 20 of Set 6 | jumla
# Processing Record 21 of Set 6 | botro
# Processing Record 22 of Set 6 | anadyr
# Processing Record 23 of Set 6 | goudomp
# City not found. Skipping...
# Processing Record 24 of Set 6 | suleja
# Processing Record 25 of Set 6 | menongue
# Processing Record 26 of Set 6 | north bend
# Processing Record 27 of Set 6 | dubinino
# Processing Record 28 of Set 6 | carnarvon
# Processing Record 29 of Set 6 | sitka
# Processing Record 30 of Set 6 | diamantino
# Processing Record 31 of Set 6 | cayenne
# Processing Record 32 of Set 6 | nara
# Processing Record 33 of Set 6 | ouesso
# Processing Record 34 of Set 6 | fortuna
# Processing Record 35 of Set 6 | srednekolymsk
# Processing Record 36 of Set 6 | ayr
# Processing Record 37 of Set 6 | vestmannaeyjar
# Processing Record 38 of Set 6 | sabang
# Processing Record 39 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 6 | alugan
# Processing Record 41 of Set 6 | deputatskiy
# Processing Record 42 of Set 6 | lebu
# Processing Record 43 of Set 6 | pernem
# Processing Record 44 of Set 6 | kupang
# Processing Record 45 of Set 6 | marystown
# Processing Record 46 of Set 6 | atka
# City not found. Skipping...
# Processing Record 47 of Set 6 | amarante
# Processing Record 48 of Set 6 | hovd
# Processing Record 49 of Set 6 | herat
# Processing Record 50 of Set 6 | rawson
# Processing Record 1 of Set 7 | baykit
# Processing Record 2 of Set 7 | morrope
# Processing Record 3 of Set 7 | sorgun
# Processing Record 4 of Set 7 | sura
# Processing Record 5 of Set 7 | port lincoln
# Processing Record 6 of Set 7 | hargeysa
# Processing Record 7 of Set 7 | maicao
# Processing Record 8 of Set 7 | le port
# Processing Record 9 of Set 7 | kawalu
# Processing Record 10 of Set 7 | olafsvik
# Processing Record 11 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 12 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 7 | saint-augustin
# Processing Record 14 of Set 7 | xacmaz
# Processing Record 15 of Set 7 | ordzhonikidze
# Processing Record 16 of Set 7 | thompson
# Processing Record 17 of Set 7 | kamuli
# Processing Record 18 of Set 7 | faanui
# Processing Record 19 of Set 7 | shache
# Processing Record 20 of Set 7 | dulyapino
# Processing Record 21 of Set 7 | mandalgovi
# Processing Record 22 of Set 7 | nikolskoye
# Processing Record 23 of Set 7 | inhambane
# Processing Record 24 of Set 7 | mandera
# Processing Record 25 of Set 7 | bosaso
# Processing Record 26 of Set 7 | osoyoos
# Processing Record 27 of Set 7 | copiapo
# Processing Record 28 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 7 | vanimo
# Processing Record 30 of Set 7 | ahtopol
# Processing Record 31 of Set 7 | sokoni
# Processing Record 32 of Set 7 | tiarei
# Processing Record 33 of Set 7 | semme
# Processing Record 34 of Set 7 | horadiz
# Processing Record 35 of Set 7 | tete
# Processing Record 36 of Set 7 | starosubkhangulovo
# Processing Record 37 of Set 7 | juneau
# Processing Record 38 of Set 7 | skjervoy
# Processing Record 39 of Set 7 | puerto carreno
# Processing Record 40 of Set 7 | khanpur
# Processing Record 41 of Set 7 | cap malheureux
# Processing Record 42 of Set 7 | nesbyen
# Processing Record 43 of Set 7 | pisco
# Processing Record 44 of Set 7 | port hardy
# Processing Record 45 of Set 7 | bengkulu
# Processing Record 46 of Set 7 | outram
# Processing Record 47 of Set 7 | mulege
# Processing Record 48 of Set 7 | salalah
# City not found. Skipping...
# Processing Record 49 of Set 7 | kununurra
# Processing Record 50 of Set 7 | broken hill
# Processing Record 1 of Set 8 | boke
# Processing Record 2 of Set 8 | lagoa
# Processing Record 3 of Set 8 | fort nelson
# Processing Record 4 of Set 8 | puerto colombia
# Processing Record 5 of Set 8 | buin
# Processing Record 6 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 7 of Set 8 | baykalovo
# Processing Record 8 of Set 8 | okato
# Processing Record 9 of Set 8 | borama
# City not found. Skipping...
# Processing Record 10 of Set 8 | encruzilhada
# Processing Record 11 of Set 8 | lokosovo
# Processing Record 12 of Set 8 | zyryanka
# Processing Record 13 of Set 8 | rundu
# Processing Record 14 of Set 8 | bathsheba
# Processing Record 15 of Set 8 | bagdarin
# Processing Record 16 of Set 8 | hue
# Processing Record 17 of Set 8 | valreas
# Processing Record 18 of Set 8 | bucosnita
# Processing Record 19 of Set 8 | sangmelima
# Processing Record 20 of Set 8 | makakilo city
# Processing Record 21 of Set 8 | ambon
# Processing Record 22 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 23 of Set 8 | hami
# Processing Record 24 of Set 8 | alofi
# Processing Record 25 of Set 8 | santa marta
# Processing Record 26 of Set 8 | vyritsa
# Processing Record 27 of Set 8 | sao joao da barra
# Processing Record 28 of Set 8 | wenatchee
# Processing Record 29 of Set 8 | sabha
# Processing Record 30 of Set 8 | mount gambier
# Processing Record 31 of Set 8 | araouane
# Processing Record 32 of Set 8 | lulea
# Processing Record 33 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 8 | mitsamiouli
# Processing Record 35 of Set 8 | kahului
# Processing Record 36 of Set 8 | vostok
# Processing Record 37 of Set 8 | tecoanapa
# Processing Record 38 of Set 8 | galesong
# Processing Record 39 of Set 8 | letnyaya stavka
# Processing Record 40 of Set 8 | ambanja
# Processing Record 41 of Set 8 | kabare
# Processing Record 42 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 8 | rio de janeiro
# Processing Record 44 of Set 8 | dunedin
# Processing Record 45 of Set 8 | cherskiy
# Processing Record 46 of Set 8 | dubna
# Processing Record 47 of Set 8 | saint augustine
# Processing Record 48 of Set 8 | mabamba
# Processing Record 49 of Set 8 | dudinka
# Processing Record 50 of Set 8 | despotovac
# Processing Record 1 of Set 9 | asyut
# Processing Record 2 of Set 9 | vidor
# Processing Record 3 of Set 9 | royan
# Processing Record 4 of Set 9 | yulara
# Processing Record 5 of Set 9 | yar-sale
# Processing Record 6 of Set 9 | kyren
# Processing Record 7 of Set 9 | jalu
# Processing Record 8 of Set 9 | oktyabrskoye
# Processing Record 9 of Set 9 | lundazi
# Processing Record 10 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 11 of Set 9 | jacareacanga
# Processing Record 12 of Set 9 | ola
# Processing Record 13 of Set 9 | mayo
# Processing Record 14 of Set 9 | buala
# Processing Record 15 of Set 9 | itoman
# Processing Record 16 of Set 9 | marawi
# Processing Record 17 of Set 9 | bowen
# Processing Record 18 of Set 9 | zhigansk
# Processing Record 19 of Set 9 | mujiayingzi
# Processing Record 20 of Set 9 | panzhihua
# Processing Record 21 of Set 9 | ketchikan
# Processing Record 22 of Set 9 | boguchany
# Processing Record 23 of Set 9 | barsesti
# City not found. Skipping...
# Processing Record 24 of Set 9 | yeletskiy
# City not found. Skipping...
# Processing Record 25 of Set 9 | tingi
# Processing Record 26 of Set 9 | scarborough
# Processing Record 27 of Set 9 | mehamn
# Processing Record 28 of Set 9 | port macquarie
# Processing Record 29 of Set 9 | karratha
# Processing Record 30 of Set 9 | puerto penasco
# Processing Record 31 of Set 9 | okhotsk
# Processing Record 32 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 9 | san cristobal
# Processing Record 34 of Set 9 | wiarton
# Processing Record 35 of Set 9 | road town
# Processing Record 36 of Set 9 | murnau
# Processing Record 37 of Set 9 | mumford
# Processing Record 38 of Set 9 | anzio
# Processing Record 39 of Set 9 | elektrenai
# Processing Record 40 of Set 9 | kangaatsiaq
# Processing Record 41 of Set 9 | margate
# Processing Record 42 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 9 | agua branca
# Processing Record 44 of Set 9 | port hedland
# Processing Record 45 of Set 9 | atar
# Processing Record 46 of Set 9 | pacifica
# Processing Record 47 of Set 9 | dalbandin
# Processing Record 48 of Set 9 | den helder
# Processing Record 49 of Set 9 | opuwo
# Processing Record 50 of Set 9 | ilebo
# Processing Record 1 of Set 10 | tukrah
# Processing Record 2 of Set 10 | namatanai
# Processing Record 3 of Set 10 | provideniya
# Processing Record 4 of Set 10 | kuressaare
# Processing Record 5 of Set 10 | sidi ali
# Processing Record 6 of Set 10 | souillac
# Processing Record 7 of Set 10 | greenwood
# Processing Record 8 of Set 10 | ilulissat
# Processing Record 9 of Set 10 | palmer
# Processing Record 10 of Set 10 | roebourne
# Processing Record 11 of Set 10 | ushtobe
# Processing Record 12 of Set 10 | saint-jean-port-joli
# Processing Record 13 of Set 10 | qafsah
# City not found. Skipping...
# Processing Record 14 of Set 10 | korla
# Processing Record 15 of Set 10 | viedma
# Processing Record 16 of Set 10 | kuah
# Processing Record 17 of Set 10 | raga
# Processing Record 18 of Set 10 | akoupe
# Processing Record 19 of Set 10 | paamiut
# Processing Record 20 of Set 10 | banyo
# Processing Record 21 of Set 10 | petershagen
# Processing Record 22 of Set 10 | boralday
# Processing Record 23 of Set 10 | kloulklubed
# Processing Record 24 of Set 10 | tam ky
# Processing Record 25 of Set 10 | nishihara
# Processing Record 26 of Set 10 | kuybyshevskiy zaton
# Processing Record 27 of Set 10 | bilibino
# Processing Record 28 of Set 10 | tartu
# Processing Record 29 of Set 10 | sorkjosen
# Processing Record 30 of Set 10 | visnes
# Processing Record 31 of Set 10 | clarence town
# Processing Record 32 of Set 10 | spornoye
# Processing Record 33 of Set 10 | zhicheng
# Processing Record 34 of Set 10 | ahipara
# Processing Record 35 of Set 10 | kapuskasing
# Processing Record 36 of Set 10 | pietarsaari
# Processing Record 37 of Set 10 | nicoya
# Processing Record 38 of Set 10 | asosa
# Processing Record 39 of Set 10 | severo-kurilsk
# Processing Record 40 of Set 10 | huainan
# Processing Record 41 of Set 10 | kwinana
# Processing Record 42 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 43 of Set 10 | baruun-urt
# Processing Record 44 of Set 10 | landau
# Processing Record 45 of Set 10 | aksu
# Processing Record 46 of Set 10 | cidreira
# Processing Record 47 of Set 10 | leopold
# Processing Record 48 of Set 10 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 49 of Set 10 | cockburn town
# Processing Record 50 of Set 10 | kraksaan
# Processing Record 1 of Set 11 | seymchan
# Processing Record 2 of Set 11 | tari
# Processing Record 3 of Set 11 | norman wells
# Processing Record 4 of Set 11 | shwebo
# Processing Record 5 of Set 11 | tocopilla
# Processing Record 6 of Set 11 | oktyabrskiy
# Processing Record 7 of Set 11 | beroroha
# Processing Record 8 of Set 11 | caiaponia
# Processing Record 9 of Set 11 | moose factory
# Processing Record 10 of Set 11 | palana
# Processing Record 11 of Set 11 | samarai
# Processing Record 12 of Set 11 | staroaleyskoye
# Processing Record 13 of Set 11 | saint-joseph
# Processing Record 14 of Set 11 | neuquen
# Processing Record 15 of Set 11 | richards bay
# Processing Record 16 of Set 11 | touros
# Processing Record 17 of Set 11 | kargasok
# Processing Record 18 of Set 11 | pizarro
# Processing Record 19 of Set 11 | raudeberg
# Processing Record 20 of Set 11 | bajo baudo
# City not found. Skipping...
# Processing Record 21 of Set 11 | nacala
# Processing Record 22 of Set 11 | hvammstangi
# City not found. Skipping...
# Processing Record 23 of Set 11 | vila velha
# Processing Record 24 of Set 11 | kalemie
# Processing Record 25 of Set 11 | rantepao
# Processing Record 26 of Set 11 | noshiro
# Processing Record 27 of Set 11 | ulladulla
# Processing Record 28 of Set 11 | veraval
# Processing Record 29 of Set 11 | sanmenxia
# Processing Record 30 of Set 11 | acapulco
# Processing Record 31 of Set 11 | camopi
# Processing Record 32 of Set 11 | bunol
# Processing Record 33 of Set 11 | kenai
# Processing Record 34 of Set 11 | mahabad
# Processing Record 35 of Set 11 | cururupu
# Processing Record 36 of Set 11 | vila do maio
# Processing Record 37 of Set 11 | savalou
# Processing Record 38 of Set 11 | libenge
# Processing Record 39 of Set 11 | pata
# Processing Record 40 of Set 11 | paciran
# Processing Record 41 of Set 11 | sirjan
# Processing Record 42 of Set 11 | phan thiet
# Processing Record 43 of Set 11 | price
# Processing Record 44 of Set 11 | bijbiara
# Processing Record 45 of Set 11 | carutapera
# Processing Record 46 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 11 | abaetetuba
# Processing Record 48 of Set 11 | zaozerne
# Processing Record 49 of Set 11 | dukat
# Processing Record 50 of Set 11 | catuday
# Processing Record 1 of Set 12 | beyneu
# Processing Record 2 of Set 12 | bahar
# Processing Record 3 of Set 12 | saint-pierre
# Processing Record 4 of Set 12 | salym
# Processing Record 5 of Set 12 | moron
# Processing Record 6 of Set 12 | dhuwaran
# Processing Record 7 of Set 12 | tabas
# Processing Record 8 of Set 12 | beloha
# Processing Record 9 of Set 12 | bay roberts
# Processing Record 10 of Set 12 | chumikan
# Processing Record 11 of Set 12 | coquimbo
# Processing Record 12 of Set 12 | porto velho
# Processing Record 13 of Set 12 | turtas
# Processing Record 14 of Set 12 | kousseri
# Processing Record 15 of Set 12 | coihaique
# Processing Record 16 of Set 12 | verkhniye tatyshly
# Processing Record 17 of Set 12 | ouadda
# Processing Record 18 of Set 12 | kamaishi
# Processing Record 19 of Set 12 | bow island
# Processing Record 20 of Set 12 | senador guiomard
# Processing Record 21 of Set 12 | tura
# Processing Record 22 of Set 12 | mawlaik
# Processing Record 23 of Set 12 | calama
# Processing Record 24 of Set 12 | barbosa ferraz
# Processing Record 25 of Set 12 | wilmington island
# Processing Record 26 of Set 12 | yarada
# Processing Record 27 of Set 12 | tessalit
# Processing Record 28 of Set 12 | husavik
# Processing Record 29 of Set 12 | hirara
# Processing Record 30 of Set 12 | bilma
# Processing Record 31 of Set 12 | dover
# Processing Record 32 of Set 12 | vardo
# Processing Record 33 of Set 12 | sao felix do xingu
# Processing Record 34 of Set 12 | westport
# Processing Record 35 of Set 12 | lerwick
# Processing Record 36 of Set 12 | lakhdenpokhya
# Processing Record 37 of Set 12 | vidyayevo
# Processing Record 38 of Set 12 | broome
# Processing Record 39 of Set 12 | irbeyskoye
# Processing Record 40 of Set 12 | werda
# Processing Record 41 of Set 12 | nador
# Processing Record 42 of Set 12 | mirabad
# Processing Record 43 of Set 12 | soyo
# Processing Record 44 of Set 12 | atambua
# Processing Record 45 of Set 12 | sinnamary
# Processing Record 46 of Set 12 | lima
# Processing Record 47 of Set 12 | hamilton
# Processing Record 48 of Set 12 | warmbad
# Processing Record 49 of Set 12 | san carlos
# Processing Record 50 of Set 12 | suntar
# Processing Record 1 of Set 13 | isangel
# Processing Record 2 of Set 13 | ewa beach
# Processing Record 3 of Set 13 | marv dasht
# City not found. Skipping...
# Processing Record 4 of Set 13 | belaya gora
# Processing Record 5 of Set 13 | port-cartier
# Processing Record 6 of Set 13 | barranca
# Processing Record 7 of Set 13 | kutum
# Processing Record 8 of Set 13 | natalio
# Processing Record 9 of Set 13 | ndola
# Processing Record 10 of Set 13 | simdega
# Processing Record 11 of Set 13 | tulcea
# Processing Record 12 of Set 13 | gizo
# Processing Record 13 of Set 13 | birin
# Processing Record 14 of Set 13 | grootfontein
# Processing Record 15 of Set 13 | peniche
# Processing Record 16 of Set 13 | leshukonskoye
# Processing Record 17 of Set 13 | saint pete beach
# Processing Record 18 of Set 13 | naftah
# City not found. Skipping...
# Processing Record 19 of Set 13 | laguna
# Processing Record 20 of Set 13 | sechura
# Processing Record 21 of Set 13 | poum
# Processing Record 22 of Set 13 | saldanha
# Processing Record 23 of Set 13 | nesterovskaya
# Processing Record 24 of Set 13 | cooma
# Processing Record 25 of Set 13 | nemuro
# Processing Record 26 of Set 13 | svidnik
# Processing Record 27 of Set 13 | staryy nadym
# Processing Record 28 of Set 13 | poya
# Processing Record 29 of Set 13 | merauke
# Processing Record 30 of Set 13 | muros
# Processing Record 31 of Set 13 | hambantota
# Processing Record 32 of Set 13 | kalmar
# Processing Record 33 of Set 13 | tunduru
# City not found. Skipping...
# Processing Record 34 of Set 13 | bocaiuva
# Processing Record 35 of Set 13 | stephenville
# Processing Record 36 of Set 13 | hokitika
# Processing Record 37 of Set 13 | saint-francois
# Processing Record 38 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 13 | senneterre
# Processing Record 40 of Set 13 | nuevo progreso
# Processing Record 41 of Set 13 | nouadhibou
# Processing Record 42 of Set 13 | campos novos
# Processing Record 43 of Set 13 | inuvik
# Processing Record 44 of Set 13 | jiangyan
# Processing Record 45 of Set 13 | magadan
# Processing Record 46 of Set 13 | marrakesh
# Processing Record 47 of Set 13 | nizwa
# Processing Record 48 of Set 13 | saint-pascal
# City not found. Skipping...
# Processing Record 49 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 13 | kondinskoye
# Processing Record 1 of Set 14 | zhangye
# Processing Record 2 of Set 14 | tsienyane
# City not found. Skipping...
# Processing Record 3 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 4 of Set 14 | oriximina
# Processing Record 5 of Set 14 | batagay-alyta
# Processing Record 6 of Set 14 | coromoro
# Processing Record 7 of Set 14 | los llanos de aridane
# Processing Record 8 of Set 14 | kermanshah
# Processing Record 9 of Set 14 | maykain
# City not found. Skipping...
# Processing Record 10 of Set 14 | iskateley
# Processing Record 11 of Set 14 | klyuchi
# Processing Record 12 of Set 14 | fayaoue
# Processing Record 13 of Set 14 | tucurui
# Processing Record 14 of Set 14 | paita
# Processing Record 15 of Set 14 | lola
# Processing Record 16 of Set 14 | rokupr
# Processing Record 17 of Set 14 | harbour breton
# Processing Record 18 of Set 14 | cravo norte
# Processing Record 19 of Set 14 | sola
# Processing Record 20 of Set 14 | kristiansund
# Processing Record 21 of Set 14 | luderitz
# Processing Record 22 of Set 14 | milove
# Processing Record 23 of Set 14 | haines junction
# Processing Record 24 of Set 14 | aasiaat
# Processing Record 25 of Set 14 | puerto quijarro
# Processing Record 26 of Set 14 | kaithal
# Processing Record 27 of Set 14 | yenagoa
# Processing Record 28 of Set 14 | aransas pass
# Processing Record 29 of Set 14 | jujuy
# City not found. Skipping...
# Processing Record 30 of Set 14 | kiama
# Processing Record 31 of Set 14 | mabaruma
# Processing Record 32 of Set 14 | rrogozhine
# Processing Record 33 of Set 14 | tongzi
# Processing Record 34 of Set 14 | doka
# Processing Record 35 of Set 14 | sao gabriel
# Processing Record 36 of Set 14 | dongkan
# Processing Record 37 of Set 14 | ponta delgada
# Processing Record 38 of Set 14 | aldan
# Processing Record 39 of Set 14 | piopio
# Processing Record 40 of Set 14 | portland
# Processing Record 41 of Set 14 | christchurch
# Processing Record 42 of Set 14 | kralendijk
# Processing Record 43 of Set 14 | malakal
# Processing Record 44 of Set 14 | oyem
# Processing Record 45 of Set 14 | verkhnevilyuysk
# Processing Record 46 of Set 14 | arman
# Processing Record 47 of Set 14 | hat yai
# Processing Record 48 of Set 14 | tupik
# Processing Record 49 of Set 14 | nema
# Processing Record 50 of Set 14 | marica
# Processing Record 1 of Set 15 | riyadh
# Processing Record 2 of Set 15 | san andres
# Processing Record 3 of Set 15 | san jose de gracia
# Processing Record 4 of Set 15 | fairbanks
# Processing Record 5 of Set 15 | veliko gradiste
# Processing Record 6 of Set 15 | santa rosa
# Processing Record 7 of Set 15 | blagoyevo
# Processing Record 8 of Set 15 | bantry
# Processing Record 9 of Set 15 | kazuno
# Processing Record 10 of Set 15 | ciras
# City not found. Skipping...
# Processing Record 11 of Set 15 | anchorage
# Processing Record 12 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 15 | takoradi
# Processing Record 14 of Set 15 | edd
# Processing Record 15 of Set 15 | katsiveli
# City not found. Skipping...
# Processing Record 16 of Set 15 | silver city
# Processing Record 17 of Set 15 | havoysund
# Processing Record 18 of Set 15 | surt
# Processing Record 19 of Set 15 | karasjok
# Processing Record 20 of Set 15 | peleduy
# Processing Record 21 of Set 15 | muzaffarabad
# Processing Record 22 of Set 15 | vagur
# Processing Record 23 of Set 15 | katangli
# Processing Record 24 of Set 15 | sistranda
# Processing Record 25 of Set 15 | majene
# Processing Record 26 of Set 15 | buraydah
# Processing Record 27 of Set 15 | ladispoli
# Processing Record 28 of Set 15 | stillwater
# Processing Record 29 of Set 15 | sur
# Processing Record 30 of Set 15 | sakakah
# Processing Record 31 of Set 15 | newport
# Processing Record 32 of Set 15 | biloela
# Processing Record 33 of Set 15 | horsham
# Processing Record 34 of Set 15 | kiboga
# Processing Record 35 of Set 15 | bhowali
# Processing Record 36 of Set 15 | santiago
# Processing Record 37 of Set 15 | burica
# City not found. Skipping...
# Processing Record 38 of Set 15 | ingham
# Processing Record 39 of Set 15 | surgut
# Processing Record 40 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 41 of Set 15 | key west
# Processing Record 42 of Set 15 | riviere-au-renard
# Processing Record 43 of Set 15 | pitimbu
# Processing Record 44 of Set 15 | yerofey pavlovich
# Processing Record 45 of Set 15 | laurel
# Processing Record 46 of Set 15 | chekhov
# Processing Record 47 of Set 15 | lodja
# Processing Record 48 of Set 15 | yerbogachen
# Processing Record 49 of Set 15 | balkanabat
# Processing Record 50 of Set 15 | dunkwa
# Processing Record 1 of Set 16 | bonfim
# Processing Record 2 of Set 16 | huntington
# Processing Record 3 of Set 16 | mineros
# Processing Record 4 of Set 16 | borisoglebskiy
# Processing Record 5 of Set 16 | xining
# Processing Record 6 of Set 16 | luena
# Processing Record 7 of Set 16 | marakkanam
# Processing Record 8 of Set 16 | port-gentil
# Processing Record 9 of Set 16 | seminole
# Processing Record 10 of Set 16 | taos
# Processing Record 11 of Set 16 | sao jose da coroa grande
# Processing Record 12 of Set 16 | antofagasta
# Processing Record 13 of Set 16 | novikovo
# Processing Record 14 of Set 16 | leh
# Processing Record 15 of Set 16 | presidencia roque saenz pena
# Processing Record 16 of Set 16 | aborlan
# Processing Record 17 of Set 16 | sovetskaya gavan
# Processing Record 18 of Set 16 | ca mau
# Processing Record 19 of Set 16 | half moon bay
# Processing Record 20 of Set 16 | evensk
# Processing Record 21 of Set 16 | camacha
# Processing Record 22 of Set 16 | yorosso
# Processing Record 23 of Set 16 | mildura
# Processing Record 24 of Set 16 | batagay
# Processing Record 25 of Set 16 | oussouye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Lavrentiya      RU  65.5833 -171.0000    281.27        73          61
# 1        Hermanus      ZA -34.4187   19.2345    286.43        91         100
# 2          Linkou      CN  45.3000  130.2833    284.75        96          11
# 3         Schwedt      DE  53.0596   14.2815    290.14        70          92
# 4         Rikitea      PF -23.1203 -134.9692    296.71        75           1
# 5        Lorengau      PG  -2.0226  147.2712    300.29        78          88
# 6  Port Elizabeth      ZA -33.9180   25.5701    285.98        82          99
# 7       Upernavik      GL  72.7868  -56.1549    278.50        86         100
# 8       Nhulunbuy      AU -12.2333  136.7667    296.49        83          75
# 9          Narsaq      GL  60.9167  -46.0500    284.27        63           9
#
#    Wind Speed      Description
# 0        6.12    broken clouds
# 1        8.72    moderate rain
# 2        1.68       few clouds
# 3        2.92  overcast clouds
# 4        5.49        clear sky
# 5        3.36  overcast clouds
# 6        3.77  overcast clouds
# 7        2.46  overcast clouds
# 8        4.63    broken clouds
# 9        4.63        clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
