# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# The zip object packs each pair of lats and lngs having the same index in their 
# respective array into a tuple

# %%
coordinates = list(lat_lngs)

cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 768

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")


# Create counters.
record_count = 1
set_count = 1   

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_name = city_weather["name"]
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        
        city_description = city_weather["weather"]
        city_description_df = pd.DataFrame(city_description)
        city_desc = city_description_df["description"].item()
  
        # Append the city information into city_data list.
        city_data.append({"City": city_name,
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kyzyl
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | nancha
# Processing Record 4 of Set 1 | okhotsk
# Processing Record 5 of Set 1 | barra velha
# Processing Record 6 of Set 1 | baixa grande
# Processing Record 7 of Set 1 | carnarvon
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | sabzevar
# Processing Record 10 of Set 1 | barrow
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | upernavik
# Processing Record 15 of Set 1 | keti bandar
# Processing Record 16 of Set 1 | northam
# Processing Record 17 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | shakiso
# Processing Record 20 of Set 1 | severo-kurilsk
# Processing Record 21 of Set 1 | altay
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | port elizabeth
# Processing Record 24 of Set 1 | buin
# Processing Record 25 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | berlevag
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | tuktoyaktuk
# Processing Record 30 of Set 1 | pevek
# Processing Record 31 of Set 1 | maldonado
# Processing Record 32 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | beringovskiy
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | puerto carreno
# Processing Record 37 of Set 1 | clyde river
# Processing Record 38 of Set 1 | huarmey
# Processing Record 39 of Set 1 | khatanga
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | longyearbyen
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | itarema
# Processing Record 44 of Set 1 | esperance
# Processing Record 45 of Set 1 | taoudenni
# Processing Record 46 of Set 1 | jamestown
# Processing Record 47 of Set 1 | icod de los vinos
# Processing Record 48 of Set 1 | ancud
# Processing Record 49 of Set 1 | ushuaia
# Processing Record 50 of Set 1 | chokurdakh
# Processing Record 1 of Set 2 | yenagoa
# Processing Record 2 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 2 | sobolevo
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | torbay
# Processing Record 6 of Set 2 | abatskoye
# Processing Record 7 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 2 | montepuez
# Processing Record 9 of Set 2 | airai
# Processing Record 10 of Set 2 | henderson
# Processing Record 11 of Set 2 | tarko-sale
# Processing Record 12 of Set 2 | payson
# City not found. Skipping...
# Processing Record 13 of Set 2 | nicoya
# Processing Record 14 of Set 2 | taseyevo
# Processing Record 15 of Set 2 | busselton
# Processing Record 16 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 2 | samarai
# Processing Record 18 of Set 2 | mataura
# Processing Record 19 of Set 2 | cidreira
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | longhua
# Processing Record 22 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 2 | socorro
# Processing Record 24 of Set 2 | villazon
# Processing Record 25 of Set 2 | anadyr
# Processing Record 26 of Set 2 | nhulunbuy
# Processing Record 27 of Set 2 | chanthaburi
# Processing Record 28 of Set 2 | yellowknife
# Processing Record 29 of Set 2 | new norfolk
# Processing Record 30 of Set 2 | elko
# Processing Record 31 of Set 2 | porto santo
# Processing Record 32 of Set 2 | fukue
# Processing Record 33 of Set 2 | yumen
# Processing Record 34 of Set 2 | zhanakorgan
# Processing Record 35 of Set 2 | zhezkazgan
# Processing Record 36 of Set 2 | bubanza
# Processing Record 37 of Set 2 | nantucket
# Processing Record 38 of Set 2 | merauke
# Processing Record 39 of Set 2 | iquique
# Processing Record 40 of Set 2 | esmeraldas
# Processing Record 41 of Set 2 | nuuk
# Processing Record 42 of Set 2 | choya
# Processing Record 43 of Set 2 | atasu
# Processing Record 44 of Set 2 | kapaa
# Processing Record 45 of Set 2 | leningradskiy
# Processing Record 46 of Set 2 | callaway
# Processing Record 47 of Set 2 | alice springs
# Processing Record 48 of Set 2 | weihai
# Processing Record 49 of Set 2 | patnos
# Processing Record 50 of Set 2 | murray bridge
# Processing Record 1 of Set 3 | la ronge
# Processing Record 2 of Set 3 | kodiak
# Processing Record 3 of Set 3 | green river
# Processing Record 4 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 3 | saskylakh
# Processing Record 6 of Set 3 | thompson
# Processing Record 7 of Set 3 | lorengau
# Processing Record 8 of Set 3 | fortuna
# Processing Record 9 of Set 3 | chulman
# Processing Record 10 of Set 3 | broome
# Processing Record 11 of Set 3 | castro
# Processing Record 12 of Set 3 | bengkulu
# Processing Record 13 of Set 3 | mahon
# Processing Record 14 of Set 3 | nantai
# Processing Record 15 of Set 3 | myszkow
# Processing Record 16 of Set 3 | yulara
# Processing Record 17 of Set 3 | morro bay
# Processing Record 18 of Set 3 | oytal
# Processing Record 19 of Set 3 | cherskiy
# Processing Record 20 of Set 3 | bayir
# Processing Record 21 of Set 3 | saint-augustin
# Processing Record 22 of Set 3 | melfi
# Processing Record 23 of Set 3 | sovetskiy
# Processing Record 24 of Set 3 | hengyang
# Processing Record 25 of Set 3 | hilo
# Processing Record 26 of Set 3 | juneau
# Processing Record 27 of Set 3 | portsmouth
# Processing Record 28 of Set 3 | lincoln
# Processing Record 29 of Set 3 | maiduguri
# Processing Record 30 of Set 3 | koubia
# Processing Record 31 of Set 3 | galesong
# Processing Record 32 of Set 3 | holme
# Processing Record 33 of Set 3 | waipawa
# Processing Record 34 of Set 3 | mogadishu
# Processing Record 35 of Set 3 | aksarayskiy
# Processing Record 36 of Set 3 | vao
# Processing Record 37 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 38 of Set 3 | coihaique
# Processing Record 39 of Set 3 | namatanai
# Processing Record 40 of Set 3 | burica
# City not found. Skipping...
# Processing Record 41 of Set 3 | hami
# Processing Record 42 of Set 3 | olinda
# Processing Record 43 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 3 | sawakin
# Processing Record 45 of Set 3 | kloulklubed
# Processing Record 46 of Set 3 | chuy
# Processing Record 47 of Set 3 | maradi
# Processing Record 48 of Set 3 | narsaq
# Processing Record 49 of Set 3 | cabo san lucas
# Processing Record 50 of Set 3 | tasiilaq
# Processing Record 1 of Set 4 | birao
# Processing Record 2 of Set 4 | salinopolis
# Processing Record 3 of Set 4 | saldanha
# Processing Record 4 of Set 4 | havre-saint-pierre
# Processing Record 5 of Set 4 | bethel
# Processing Record 6 of Set 4 | gold coast
# Processing Record 7 of Set 4 | jodhpur
# Processing Record 8 of Set 4 | sidrolandia
# Processing Record 9 of Set 4 | flinders
# Processing Record 10 of Set 4 | kushiro
# Processing Record 11 of Set 4 | marienburg
# Processing Record 12 of Set 4 | kukushtan
# Processing Record 13 of Set 4 | touros
# Processing Record 14 of Set 4 | rincon
# Processing Record 15 of Set 4 | vallenar
# Processing Record 16 of Set 4 | saint-philippe
# Processing Record 17 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 4 | bambous virieux
# Processing Record 19 of Set 4 | barra do garcas
# Processing Record 20 of Set 4 | provideniya
# Processing Record 21 of Set 4 | nikolskoye
# Processing Record 22 of Set 4 | port lincoln
# Processing Record 23 of Set 4 | laon
# Processing Record 24 of Set 4 | seybaplaya
# Processing Record 25 of Set 4 | havoysund
# Processing Record 26 of Set 4 | mahebourg
# Processing Record 27 of Set 4 | mount gambier
# Processing Record 28 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 29 of Set 4 | salalah
# Processing Record 30 of Set 4 | luderitz
# Processing Record 31 of Set 4 | lima
# Processing Record 32 of Set 4 | sioux lookout
# Processing Record 33 of Set 4 | norman wells
# Processing Record 34 of Set 4 | portobelo
# Processing Record 35 of Set 4 | nouadhibou
# Processing Record 36 of Set 4 | maceio
# Processing Record 37 of Set 4 | talnakh
# Processing Record 38 of Set 4 | nome
# Processing Record 39 of Set 4 | kahului
# Processing Record 40 of Set 4 | lagoa
# Processing Record 41 of Set 4 | calbuco
# Processing Record 42 of Set 4 | kingsville
# Processing Record 43 of Set 4 | log
# Processing Record 44 of Set 4 | avarua
# Processing Record 45 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 4 | otradnoye
# Processing Record 47 of Set 4 | tecoanapa
# Processing Record 48 of Set 4 | victoria
# Processing Record 49 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 4 | pisco
# Processing Record 1 of Set 5 | mount isa
# Processing Record 2 of Set 5 | marawi
# Processing Record 3 of Set 5 | mapastepec
# Processing Record 4 of Set 5 | wuan
# Processing Record 5 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 5 | porlamar
# Processing Record 7 of Set 5 | colares
# Processing Record 8 of Set 5 | avera
# Processing Record 9 of Set 5 | moose factory
# Processing Record 10 of Set 5 | praya
# Processing Record 11 of Set 5 | ballina
# Processing Record 12 of Set 5 | kysyl-syr
# Processing Record 13 of Set 5 | linchuan
# City not found. Skipping...
# Processing Record 14 of Set 5 | grafton
# Processing Record 15 of Set 5 | coquimbo
# Processing Record 16 of Set 5 | jacareacanga
# Processing Record 17 of Set 5 | kuryk
# Processing Record 18 of Set 5 | san patricio
# Processing Record 19 of Set 5 | georgetown
# Processing Record 20 of Set 5 | rupert
# Processing Record 21 of Set 5 | ahipara
# Processing Record 22 of Set 5 | sept-iles
# Processing Record 23 of Set 5 | mirina
# City not found. Skipping...
# Processing Record 24 of Set 5 | deputatskiy
# Processing Record 25 of Set 5 | billings
# City not found. Skipping...
# Processing Record 26 of Set 5 | mar del plata
# Processing Record 27 of Set 5 | san andres
# Processing Record 28 of Set 5 | quatre cocos
# Processing Record 29 of Set 5 | portland
# Processing Record 30 of Set 5 | vila velha
# Processing Record 31 of Set 5 | felidhoo
# City not found. Skipping...
# Processing Record 32 of Set 5 | vilyuysk
# Processing Record 33 of Set 5 | dwarka
# Processing Record 34 of Set 5 | laguna
# Processing Record 35 of Set 5 | rostaq
# City not found. Skipping...
# Processing Record 36 of Set 5 | george
# Processing Record 37 of Set 5 | pafos
# Processing Record 38 of Set 5 | udachnyy
# Processing Record 39 of Set 5 | kaitangata
# Processing Record 40 of Set 5 | saint george
# Processing Record 41 of Set 5 | juliaca
# Processing Record 42 of Set 5 | vestmannaeyjar
# Processing Record 43 of Set 5 | morros
# Processing Record 44 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 5 | miandrivazo
# Processing Record 46 of Set 5 | shawnee
# Processing Record 47 of Set 5 | brae
# Processing Record 48 of Set 5 | oistins
# Processing Record 49 of Set 5 | brasileia
# Processing Record 50 of Set 5 | kolpashevo
# Processing Record 1 of Set 6 | dukat
# Processing Record 2 of Set 6 | tabou
# Processing Record 3 of Set 6 | katubao
# Processing Record 4 of Set 6 | sur
# Processing Record 5 of Set 6 | ilave
# Processing Record 6 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 6 | jaicos
# Processing Record 8 of Set 6 | liepaja
# Processing Record 9 of Set 6 | concarneau
# Processing Record 10 of Set 6 | vastervik
# City not found. Skipping...
# Processing Record 11 of Set 6 | kirensk
# Processing Record 12 of Set 6 | batticaloa
# Processing Record 13 of Set 6 | fort saint james
# Processing Record 14 of Set 6 | namibe
# Processing Record 15 of Set 6 | penhold
# Processing Record 16 of Set 6 | tessalit
# Processing Record 17 of Set 6 | bokspits
# City not found. Skipping...
# Processing Record 18 of Set 6 | geraldton
# Processing Record 19 of Set 6 | arlit
# Processing Record 20 of Set 6 | faanui
# Processing Record 21 of Set 6 | hithadhoo
# Processing Record 22 of Set 6 | kalawit
# Processing Record 23 of Set 6 | barranca
# Processing Record 24 of Set 6 | souillac
# Processing Record 25 of Set 6 | uzunovo
# Processing Record 26 of Set 6 | hoquiam
# Processing Record 27 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 6 | norrtalje
# Processing Record 29 of Set 6 | beneditinos
# Processing Record 30 of Set 6 | carroll
# Processing Record 31 of Set 6 | port blair
# Processing Record 32 of Set 6 | hasaki
# Processing Record 33 of Set 6 | toora-khem
# Processing Record 34 of Set 6 | aklavik
# Processing Record 35 of Set 6 | valparaiso
# Processing Record 36 of Set 6 | stornoway
# Processing Record 37 of Set 6 | sao joao da barra
# Processing Record 38 of Set 6 | alofi
# Processing Record 39 of Set 6 | tuatapere
# Processing Record 40 of Set 6 | vanino
# Processing Record 41 of Set 6 | port hedland
# Processing Record 42 of Set 6 | miri
# Processing Record 43 of Set 6 | alwar
# Processing Record 44 of Set 6 | baglung
# Processing Record 45 of Set 6 | yatou
# Processing Record 46 of Set 6 | coahuayana
# Processing Record 47 of Set 6 | ondjiva
# Processing Record 48 of Set 6 | seydi
# Processing Record 49 of Set 6 | kununurra
# Processing Record 50 of Set 6 | asau
# Processing Record 1 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 7 | sicuani
# Processing Record 3 of Set 7 | tiznit
# Processing Record 4 of Set 7 | belmonte
# Processing Record 5 of Set 7 | hanchuan
# Processing Record 6 of Set 7 | hualmay
# Processing Record 7 of Set 7 | harper
# Processing Record 8 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 7 | lompoc
# Processing Record 10 of Set 7 | pangkalanbuun
# Processing Record 11 of Set 7 | cayhagan
# Processing Record 12 of Set 7 | san quintin
# Processing Record 13 of Set 7 | korla
# Processing Record 14 of Set 7 | toftir
# City not found. Skipping...
# Processing Record 15 of Set 7 | saint-georges
# Processing Record 16 of Set 7 | matara
# Processing Record 17 of Set 7 | kemin
# Processing Record 18 of Set 7 | xining
# Processing Record 19 of Set 7 | turayf
# Processing Record 20 of Set 7 | cockburn town
# Processing Record 21 of Set 7 | shihezi
# Processing Record 22 of Set 7 | bhadasar
# Processing Record 23 of Set 7 | baruun-urt
# Processing Record 24 of Set 7 | pathein
# Processing Record 25 of Set 7 | kutum
# Processing Record 26 of Set 7 | baisha
# Processing Record 27 of Set 7 | dikson
# Processing Record 28 of Set 7 | sao filipe
# Processing Record 29 of Set 7 | amahai
# Processing Record 30 of Set 7 | rio grande
# Processing Record 31 of Set 7 | aboisso
# Processing Record 32 of Set 7 | bilibino
# Processing Record 33 of Set 7 | amsterdam
# Processing Record 34 of Set 7 | ahuimanu
# Processing Record 35 of Set 7 | awbari
# Processing Record 36 of Set 7 | ketchikan
# Processing Record 37 of Set 7 | aiken
# Processing Record 38 of Set 7 | resistencia
# Processing Record 39 of Set 7 | kiama
# Processing Record 40 of Set 7 | ribeira grande
# Processing Record 41 of Set 7 | qui nhon
# Processing Record 42 of Set 7 | machilipatnam
# Processing Record 43 of Set 7 | oranjemund
# Processing Record 44 of Set 7 | ilinskiy
# Processing Record 45 of Set 7 | srednekolymsk
# Processing Record 46 of Set 7 | americus
# Processing Record 47 of Set 7 | porto novo
# Processing Record 48 of Set 7 | honningsvag
# Processing Record 49 of Set 7 | concepcion
# Processing Record 50 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 8 | hamilton
# Processing Record 2 of Set 8 | shingu
# Processing Record 3 of Set 8 | curaca
# Processing Record 4 of Set 8 | holalkere
# Processing Record 5 of Set 8 | rabo de peixe
# Processing Record 6 of Set 8 | elbeuf
# Processing Record 7 of Set 8 | zaragoza
# Processing Record 8 of Set 8 | nizhniy kuranakh
# Processing Record 9 of Set 8 | kavieng
# Processing Record 10 of Set 8 | qaqortoq
# Processing Record 11 of Set 8 | kudahuvadhoo
# Processing Record 12 of Set 8 | chibombo
# Processing Record 13 of Set 8 | kozienice
# Processing Record 14 of Set 8 | vila franca do campo
# Processing Record 15 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 8 | caborca
# Processing Record 17 of Set 8 | ponta do sol
# Processing Record 18 of Set 8 | mubende
# Processing Record 19 of Set 8 | acarau
# Processing Record 20 of Set 8 | tiksi
# Processing Record 21 of Set 8 | praia
# Processing Record 22 of Set 8 | saint-leu
# Processing Record 23 of Set 8 | veraval
# Processing Record 24 of Set 8 | josefina
# Processing Record 25 of Set 8 | balgazyn
# Processing Record 26 of Set 8 | caravelas
# Processing Record 27 of Set 8 | saint-pierre
# Processing Record 28 of Set 8 | singaraja
# Processing Record 29 of Set 8 | saint anthony
# Processing Record 30 of Set 8 | parichhatgarh
# Processing Record 31 of Set 8 | nanortalik
# Processing Record 32 of Set 8 | east london
# Processing Record 33 of Set 8 | san angelo
# Processing Record 34 of Set 8 | college
# Processing Record 35 of Set 8 | shushtar
# Processing Record 36 of Set 8 | sistranda
# Processing Record 37 of Set 8 | dingle
# Processing Record 38 of Set 8 | klaksvik
# Processing Record 39 of Set 8 | bridlington
# Processing Record 40 of Set 8 | boende
# Processing Record 41 of Set 8 | parana
# Processing Record 42 of Set 8 | lalganj
# Processing Record 43 of Set 8 | tonantins
# Processing Record 44 of Set 8 | preobrazheniye
# Processing Record 45 of Set 8 | villa maria
# Processing Record 46 of Set 8 | mayor pablo lagerenza
# Processing Record 47 of Set 8 | kamen-na-obi
# Processing Record 48 of Set 8 | vandoeuvre-les-nancy
# Processing Record 49 of Set 8 | marrakesh
# Processing Record 50 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 1 of Set 9 | ust-koksa
# Processing Record 2 of Set 9 | soure
# Processing Record 3 of Set 9 | methoni
# Processing Record 4 of Set 9 | faya
# Processing Record 5 of Set 9 | ust-nera
# Processing Record 6 of Set 9 | othonoi
# City not found. Skipping...
# Processing Record 7 of Set 9 | warrington
# Processing Record 8 of Set 9 | palmer
# Processing Record 9 of Set 9 | charleston
# Processing Record 10 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 9 | plettenberg bay
# Processing Record 12 of Set 9 | neiafu
# Processing Record 13 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 14 of Set 9 | makueni
# Processing Record 15 of Set 9 | umm durman
# City not found. Skipping...
# Processing Record 16 of Set 9 | pasighat
# Processing Record 17 of Set 9 | oranjestad
# Processing Record 18 of Set 9 | vanimo
# Processing Record 19 of Set 9 | sungaipenuh
# Processing Record 20 of Set 9 | kruisfontein
# Processing Record 21 of Set 9 | zhitikara
# City not found. Skipping...
# Processing Record 22 of Set 9 | buala
# Processing Record 23 of Set 9 | toamasina
# Processing Record 24 of Set 9 | tucurui
# Processing Record 25 of Set 9 | meulaboh
# Processing Record 26 of Set 9 | iaciara
# Processing Record 27 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 28 of Set 9 | shimoda
# Processing Record 29 of Set 9 | hambantota
# Processing Record 30 of Set 9 | pilar
# Processing Record 31 of Set 9 | beaverlodge
# Processing Record 32 of Set 9 | charagua
# Processing Record 33 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 34 of Set 9 | launceston
# Processing Record 35 of Set 9 | vestmanna
# Processing Record 36 of Set 9 | ulladulla
# Processing Record 37 of Set 9 | lodwar
# Processing Record 38 of Set 9 | lodi
# Processing Record 39 of Set 9 | chumikan
# Processing Record 40 of Set 9 | san rafael
# Processing Record 41 of Set 9 | san cristobal
# Processing Record 42 of Set 9 | santa rosa
# Processing Record 43 of Set 9 | umba
# Processing Record 44 of Set 9 | sambava
# Processing Record 45 of Set 9 | cap malheureux
# Processing Record 46 of Set 9 | swan river
# Processing Record 47 of Set 9 | eyl
# Processing Record 48 of Set 9 | tekeli
# Processing Record 49 of Set 9 | te anau
# Processing Record 50 of Set 9 | agucadoura
# Processing Record 1 of Set 10 | calama
# Processing Record 2 of Set 10 | baykit
# Processing Record 3 of Set 10 | kansanshi
# Processing Record 4 of Set 10 | durgapur
# Processing Record 5 of Set 10 | chicama
# Processing Record 6 of Set 10 | pangnirtung
# Processing Record 7 of Set 10 | pocerski pricinovic
# Processing Record 8 of Set 10 | codrington
# Processing Record 9 of Set 10 | fare
# Processing Record 10 of Set 10 | nemuro
# Processing Record 11 of Set 10 | matagami
# Processing Record 12 of Set 10 | surgut
# Processing Record 13 of Set 10 | salmas
# Processing Record 14 of Set 10 | noumea
# Processing Record 15 of Set 10 | mehamn
# Processing Record 16 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 10 | skibbereen
# Processing Record 18 of Set 10 | katsuura
# Processing Record 19 of Set 10 | yashiro
# Processing Record 20 of Set 10 | khani
# Processing Record 21 of Set 10 | pulaski
# Processing Record 22 of Set 10 | loikaw
# Processing Record 23 of Set 10 | rumford
# Processing Record 24 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 25 of Set 10 | borovskoy
# Processing Record 26 of Set 10 | negru voda
# Processing Record 27 of Set 10 | ust-kuyga
# Processing Record 28 of Set 10 | zamora
# Processing Record 29 of Set 10 | storsteinnes
# Processing Record 30 of Set 10 | najran
# Processing Record 31 of Set 10 | nadym
# Processing Record 32 of Set 10 | pascagoula
# Processing Record 33 of Set 10 | coatlan
# City not found. Skipping...
# Processing Record 34 of Set 10 | west odessa
# Processing Record 35 of Set 10 | placido de castro
# Processing Record 36 of Set 10 | karatu
# Processing Record 37 of Set 10 | wattegama
# Processing Record 38 of Set 10 | nyimba
# Processing Record 39 of Set 10 | naica
# Processing Record 40 of Set 10 | kawhia
# Processing Record 41 of Set 10 | caloundra
# Processing Record 42 of Set 10 | houma
# Processing Record 43 of Set 10 | thunder bay
# Processing Record 44 of Set 10 | xudat
# Processing Record 45 of Set 10 | ouesso
# Processing Record 46 of Set 10 | mantua
# Processing Record 47 of Set 10 | kieta
# Processing Record 48 of Set 10 | jaszapati
# Processing Record 49 of Set 10 | zhigansk
# Processing Record 50 of Set 10 | fairbanks
# Processing Record 1 of Set 11 | gat
# Processing Record 2 of Set 11 | tura
# Processing Record 3 of Set 11 | sawtell
# Processing Record 4 of Set 11 | ambilobe
# Processing Record 5 of Set 11 | shenjiamen
# Processing Record 6 of Set 11 | magistralnyy
# Processing Record 7 of Set 11 | gizo
# Processing Record 8 of Set 11 | banda aceh
# Processing Record 9 of Set 11 | sitka
# Processing Record 10 of Set 11 | eureka
# Processing Record 11 of Set 11 | itaocara
# Processing Record 12 of Set 11 | layou
# Processing Record 13 of Set 11 | la palma
# Processing Record 14 of Set 11 | rio sereno
# Processing Record 15 of Set 11 | saint-joseph
# Processing Record 16 of Set 11 | bergama
# Processing Record 17 of Set 11 | lauterach
# Processing Record 18 of Set 11 | antonina
# Processing Record 19 of Set 11 | palmas
# Processing Record 20 of Set 11 | hovd
# Processing Record 21 of Set 11 | kharabali
# Processing Record 22 of Set 11 | prince rupert
# Processing Record 23 of Set 11 | morehead
# Processing Record 24 of Set 11 | kavaratti
# Processing Record 25 of Set 11 | ilulissat
# Processing Record 26 of Set 11 | mattru
# Processing Record 27 of Set 11 | kerrville
# Processing Record 28 of Set 11 | porto nacional
# Processing Record 29 of Set 11 | paamiut
# Processing Record 30 of Set 11 | ziro
# Processing Record 31 of Set 11 | bathsheba
# Processing Record 32 of Set 11 | puerto escondido
# Processing Record 33 of Set 11 | jalu
# Processing Record 34 of Set 11 | jumla
# Processing Record 35 of Set 11 | shubarshi
# Processing Record 36 of Set 11 | ardistan
# City not found. Skipping...
# Processing Record 37 of Set 11 | gander
# Processing Record 38 of Set 11 | kankan
# Processing Record 39 of Set 11 | vostok
# Processing Record 40 of Set 11 | maputo
# Processing Record 41 of Set 11 | jiayuguan
# Processing Record 42 of Set 11 | playa vicente
# Processing Record 43 of Set 11 | viedma
# Processing Record 44 of Set 11 | bossangoa
# Processing Record 45 of Set 11 | anamur
# Processing Record 46 of Set 11 | yaan
# Processing Record 47 of Set 11 | pinar del rio
# Processing Record 48 of Set 11 | pandan
# Processing Record 49 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 50 of Set 11 | zholymbet
# Processing Record 1 of Set 12 | turbat
# Processing Record 2 of Set 12 | santa maria
# Processing Record 3 of Set 12 | ambunti
# Processing Record 4 of Set 12 | shivrajpur
# Processing Record 5 of Set 12 | uruzgan
# Processing Record 6 of Set 12 | san felipe
# Processing Record 7 of Set 12 | samaipata
# Processing Record 8 of Set 12 | duz
# City not found. Skipping...
# Processing Record 9 of Set 12 | salta
# Processing Record 10 of Set 12 | machachi
# Processing Record 11 of Set 12 | bagotville
# Processing Record 12 of Set 12 | paraiso
# Processing Record 13 of Set 12 | havre
# Processing Record 14 of Set 12 | ambalavao
# Processing Record 15 of Set 12 | tokur
# Processing Record 16 of Set 12 | richard toll
# City not found. Skipping...
# Processing Record 17 of Set 12 | bolshoy uluy
# City not found. Skipping...
# Processing Record 18 of Set 12 | san policarpo
# Processing Record 19 of Set 12 | mandalgovi
# Processing Record 20 of Set 12 | irbit
# Processing Record 21 of Set 12 | fez
# Processing Record 22 of Set 12 | abu samrah
# Processing Record 23 of Set 12 | carberry
# Processing Record 24 of Set 12 | rameswaram
# Processing Record 25 of Set 12 | hokitika
# Processing Record 26 of Set 12 | bulgan
# Processing Record 27 of Set 12 | sao miguel do araguaia
# Processing Record 28 of Set 12 | isangel
# Processing Record 29 of Set 12 | mahendranagar
# Processing Record 30 of Set 12 | lebu
# Processing Record 31 of Set 12 | zaterechnyy
# Processing Record 32 of Set 12 | phatthalung
# Processing Record 33 of Set 12 | iranshahr
# Processing Record 34 of Set 12 | seoul
# Processing Record 35 of Set 12 | cristalina
# Processing Record 36 of Set 12 | moerai
# Processing Record 37 of Set 12 | dromolaxia
# Processing Record 38 of Set 12 | batemans bay
# Processing Record 39 of Set 12 | bereda
# Processing Record 40 of Set 12 | vahan
# Processing Record 41 of Set 12 | marsa matruh
# Processing Record 42 of Set 12 | katha
# City not found. Skipping...
# Processing Record 43 of Set 12 | iisalmi
# Processing Record 44 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 12 | lensk
# Processing Record 46 of Set 12 | wellington
# Processing Record 47 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 48 of Set 12 | eirunepe
# Processing Record 49 of Set 12 | hobyo
# Processing Record 50 of Set 12 | erzin
# Processing Record 1 of Set 13 | nelson bay
# Processing Record 2 of Set 13 | hammerfest
# Processing Record 3 of Set 13 | kuhestan
# City not found. Skipping...
# Processing Record 4 of Set 13 | zakamensk
# Processing Record 5 of Set 13 | tugulym
# Processing Record 6 of Set 13 | poum
# Processing Record 7 of Set 13 | morgan city
# Processing Record 8 of Set 13 | batagay-alyta
# Processing Record 9 of Set 13 | necochea
# Processing Record 10 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 13 | yate
# Processing Record 12 of Set 13 | verkhnyaya sinyachikha
# Processing Record 13 of Set 13 | bor
# Processing Record 14 of Set 13 | westport
# Processing Record 15 of Set 13 | rio gallegos
# Processing Record 16 of Set 13 | mareeba
# Processing Record 17 of Set 13 | katherine
# Processing Record 18 of Set 13 | ushtobe
# Processing Record 19 of Set 13 | haines junction
# Processing Record 20 of Set 13 | casambalangan
# Processing Record 21 of Set 13 | ape
# Processing Record 22 of Set 13 | santa catarina de tepehuanes
# Processing Record 23 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 24 of Set 13 | chegdomyn
# Processing Record 25 of Set 13 | kolokani
# Processing Record 26 of Set 13 | los llanos de aridane
# Processing Record 27 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 28 of Set 13 | florianopolis
# Processing Record 29 of Set 13 | yar-sale
# Processing Record 30 of Set 13 | frosinone
# Processing Record 31 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 32 of Set 13 | junagarh
# Processing Record 33 of Set 13 | pionerskiy
# Processing Record 34 of Set 13 | jogindarnagar
# Processing Record 35 of Set 13 | yerbogachen
# Processing Record 36 of Set 13 | luau
# Processing Record 37 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 38 of Set 13 | gloversville
# Processing Record 39 of Set 13 | bushehr
# Processing Record 40 of Set 13 | kidodi
# Processing Record 41 of Set 13 | asyut
# Processing Record 42 of Set 13 | tautira
# Processing Record 43 of Set 13 | namtsy
# Processing Record 44 of Set 13 | neustadt
# Processing Record 45 of Set 13 | de-kastri
# Processing Record 46 of Set 13 | constitucion
# Processing Record 47 of Set 13 | valley city
# Processing Record 48 of Set 13 | susanville
# Processing Record 49 of Set 13 | soto la marina
# Processing Record 50 of Set 13 | grevenbroich
# Processing Record 1 of Set 14 | krasnoselkup
# Processing Record 2 of Set 14 | matamoros
# Processing Record 3 of Set 14 | broken hill
# Processing Record 4 of Set 14 | lunenburg
# Processing Record 5 of Set 14 | cayenne
# Processing Record 6 of Set 14 | ruteng
# Processing Record 7 of Set 14 | batagay
# Processing Record 8 of Set 14 | salym
# Processing Record 9 of Set 14 | ornskoldsvik
# Processing Record 10 of Set 14 | kargasok
# Processing Record 11 of Set 14 | chukhloma
# Processing Record 12 of Set 14 | hihya
# Processing Record 13 of Set 14 | rovaniemi
# Processing Record 14 of Set 14 | mitu
# Processing Record 15 of Set 14 | coban
# Processing Record 16 of Set 14 | stromness
# Processing Record 17 of Set 14 | tenenkou
# Processing Record 18 of Set 14 | kannangad
# Processing Record 19 of Set 14 | skiros
# City not found. Skipping...
# Processing Record 20 of Set 14 | ponta delgada
# Processing Record 21 of Set 14 | bandarbeyla
# Processing Record 22 of Set 14 | akdepe
# Processing Record 23 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 14 | kyra
# Processing Record 25 of Set 14 | xinqing
# Processing Record 26 of Set 14 | novogagatli
# Processing Record 27 of Set 14 | jieshi
# Processing Record 28 of Set 14 | buraydah
# Processing Record 29 of Set 14 | bialystok
# Processing Record 30 of Set 14 | kidal
# Processing Record 31 of Set 14 | sherpur
# Processing Record 32 of Set 14 | port hardy
# Processing Record 33 of Set 14 | iwanai
# Processing Record 34 of Set 14 | sorong
# Processing Record 35 of Set 14 | puerto narino
# Processing Record 36 of Set 14 | naron
# Processing Record 37 of Set 14 | great yarmouth
# Processing Record 38 of Set 14 | lerwick
# Processing Record 39 of Set 14 | oktyabrskoye
# Processing Record 40 of Set 14 | herat
# Processing Record 41 of Set 14 | safaga
# Processing Record 42 of Set 14 | gazanjyk
# Processing Record 43 of Set 14 | siocon
# Processing Record 44 of Set 14 | tazovskiy
# Processing Record 45 of Set 14 | cerro largo
# Processing Record 46 of Set 14 | flin flon
# Processing Record 47 of Set 14 | nishihara
# Processing Record 48 of Set 14 | zdvinsk
# Processing Record 49 of Set 14 | great falls
# Processing Record 50 of Set 14 | mikhaylovka
# Processing Record 1 of Set 15 | makakilo city
# Processing Record 2 of Set 15 | padang
# Processing Record 3 of Set 15 | hegang
# Processing Record 4 of Set 15 | bonthe
# Processing Record 5 of Set 15 | tezu
# Processing Record 6 of Set 15 | russell
# Processing Record 7 of Set 15 | morondava
# Processing Record 8 of Set 15 | buchanan
# Processing Record 9 of Set 15 | destin
# Processing Record 10 of Set 15 | gatton
# Processing Record 11 of Set 15 | merritt island
# Processing Record 12 of Set 15 | waycross
# Processing Record 13 of Set 15 | changji
# Processing Record 14 of Set 15 | ritchie
# Processing Record 15 of Set 15 | reyes
# Processing Record 16 of Set 15 | deniliquin
# Processing Record 17 of Set 15 | el tocuyo
# Processing Record 18 of Set 15 | orocue
# Processing Record 19 of Set 15 | hofn
# Processing Record 20 of Set 15 | buta
# Processing Record 21 of Set 15 | beloha
# Processing Record 22 of Set 15 | unye
# City not found. Skipping...
# Processing Record 23 of Set 15 | poso
# Processing Record 24 of Set 15 | guaxupe
# Processing Record 25 of Set 15 | kangaatsiaq
# Processing Record 26 of Set 15 | chincha alta
# Processing Record 27 of Set 15 | port-gentil
# Processing Record 28 of Set 15 | shanhetun
# Processing Record 29 of Set 15 | port keats
# Processing Record 30 of Set 15 | tela
# Processing Record 31 of Set 15 | kasempa
# Processing Record 32 of Set 15 | kurilsk
# Processing Record 33 of Set 15 | severnyy
# Processing Record 34 of Set 15 | vardo
# Processing Record 35 of Set 15 | kattivakkam
# Processing Record 36 of Set 15 | mfou
# Processing Record 37 of Set 15 | pervomayskoye
# Processing Record 38 of Set 15 | marquette
# Processing Record 39 of Set 15 | orchard homes
# Processing Record 40 of Set 15 | tadine
# Processing Record 41 of Set 15 | semenivka
# Processing Record 42 of Set 15 | san blas
# Processing Record 43 of Set 15 | banjarmasin
# Processing Record 44 of Set 15 | kingsport
# Processing Record 45 of Set 15 | mezen
# Processing Record 46 of Set 15 | alexandria
# Processing Record 47 of Set 15 | lasa
# Processing Record 48 of Set 15 | somerset
# Processing Record 49 of Set 15 | antofagasta
# Processing Record 50 of Set 15 | abu dhabi
# Processing Record 1 of Set 16 | dunedin
# Processing Record 2 of Set 16 | san isidro
# Processing Record 3 of Set 16 | olafsvik
# Processing Record 4 of Set 16 | paducah
# Processing Record 5 of Set 16 | kautokeino
# Processing Record 6 of Set 16 | inhambane
# Processing Record 7 of Set 16 | kupang
# Processing Record 8 of Set 16 | atar
# Processing Record 9 of Set 16 | norwalk
# Processing Record 10 of Set 16 | lermontovka
# Processing Record 11 of Set 16 | rocha
# Processing Record 12 of Set 16 | mbengwi
# Processing Record 13 of Set 16 | nago
# Processing Record 14 of Set 16 | mendi
# Processing Record 15 of Set 16 | rendsburg
# Processing Record 16 of Set 16 | xiantao
# Processing Record 17 of Set 16 | sindor
# Processing Record 18 of Set 16 | nizhniy ufaley
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Kyzyl      RU  51.7000   94.4500     60.03        75          87
# 1  Puerto Ayora      EC  -0.7393  -90.3518     70.56        87          45
# 2        Lianhe      CN  47.1333  129.2667     56.44        87         100
# 3       Okhotsk      RU  59.3833  143.3000     64.11        69          24
# 4   Barra Velha      BR -26.6322  -48.6847     64.31        96           1
# 5  Baixa Grande      BR -11.9597  -40.1681     66.20        91          78
# 6     Carnarvon      AU -24.8667  113.6333     64.47        81          90
# 7     Cape Town      ZA -33.9258   18.4232     55.11        92          75
# 8      Sabzawār      IR  36.2126   57.6819     81.39        18           0
# 9        Barrow      US  71.2906 -156.7887     39.22        88          90
#
#    Wind Speed       Description
# 0        2.93   overcast clouds
# 1        7.00  scattered clouds
# 2        3.18   overcast clouds
# 3        7.83        few clouds
# 4        3.40         clear sky
# 5        7.36     broken clouds
# 6        6.91   overcast clouds
# 7        3.00        light rain
# 8        6.69         clear sky
# 9       11.50              mist

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
